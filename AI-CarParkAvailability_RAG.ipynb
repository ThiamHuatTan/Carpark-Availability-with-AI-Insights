# %%
# ==========================
# 1) SETUP
# ==========================
from pyspark.sql.functions import regexp_replace, col, when, avg, coalesce, concat, round, udf, monotonically_increasing_id
from pyspark.sql.types import StringType, ArrayType, FloatType
import requests, os
import openai
from pyspark.sql import SparkSession
from datetime import datetime
import pandas as pd
from concurrent.futures import ThreadPoolExecutor
from openai import OpenAI
import os

# Set OpenAI key before creating Spark session
os.environ["OPENAI_API_KEY"] = "PUT YOUR OPENAI API KEY HERE"

# Create Spark session in Fabric
spark = SparkSession.builder.getOrCreate()
# Out:
# StatementMeta(, 67ab9028-33b0-45ae-a06e-69ff47ba6cce, 5, Finished, Available, Finished)

# %%
# ==========================
# 2) EXTRACT DATA FROM API
# ==========================
url = "https://api.data.gov.sg/v1/transport/carpark-availability"
response = requests.get(url)
data = response.json()

# Flatten JSON
carparks = []
for item in data['items'][0]['carpark_data']:
    carparks.append({
        "carpark_number": item["carpark_number"],
        "total_lots": int(item["carpark_info"][0]["total_lots"]),
        "lots_available": int(item["carpark_info"][0]["lots_available"]),
        "update_datetime": item["update_datetime"]
    })

# Convert to Spark DataFrame
df = spark.createDataFrame(carparks)
# Out:
# StatementMeta(, 67ab9028-33b0-45ae-a06e-69ff47ba6cce, 6, Finished, Available, Finished)

# %%
# Download file here: https://beta.data.gov.sg/datasets/148/view
# Then upload to /Files
# Purpose is to get the address from the above downloaded data, because carparks does not contain address
# Out:
# StatementMeta(, 67ab9028-33b0-45ae-a06e-69ff47ba6cce, 7, Finished, Available, Finished)

# %%
data = spark.read.csv("Files/HDBCarparkInformation.csv", header=True, inferSchema=True)
data = data.withColumnRenamed('car_park_no', 'carpark_number')
# Out:
# StatementMeta(, 67ab9028-33b0-45ae-a06e-69ff47ba6cce, 8, Finished, Available, Finished)

# %%
merged_df = df.join(data, on='carpark_number', how='inner')
# Remove 'BLK' and 'BLOCK' from the 'address' column
merged_df = merged_df.withColumn('address', regexp_replace(col('address'), 'BLK', ''))
merged_df = merged_df.withColumn('address', regexp_replace(col('address'), 'BLOCK', ''))
# Out:
# StatementMeta(, 67ab9028-33b0-45ae-a06e-69ff47ba6cce, 9, Finished, Available, Finished)

# %%
def remove_text(address):
    separators = ["/", "-", ",", "&", "TO "]
    for separator in separators:
        if separator in address:
            parts = address.split(separator)
            address = parts[-1].strip()                
    return address.strip()
# Out:
# StatementMeta(, 67ab9028-33b0-45ae-a06e-69ff47ba6cce, 10, Finished, Available, Finished)

# %%
# Convert it to a PySpark UDF
remove_text_udf = udf(remove_text, StringType())

# Apply it to the 'address' column
merged_df = merged_df.withColumn(
    'address', 
    remove_text_udf(col('address'))
)
# Out:
# StatementMeta(, 67ab9028-33b0-45ae-a06e-69ff47ba6cce, 11, Finished, Available, Finished)

# %%
# https://towardsdatascience.com/geocoding-singapore-coordinates-onemap-api-3e1542bf26f7
# https://github.com/shawnthamks/OneMap-API
# https://www.onemap.gov.sg/apidocs/apidocs/#search

def get_coordinates(addresses):
    url = 'https://www.onemap.gov.sg/api/common/elastic/search'
    coordinates_list = []

    for address in addresslist:
        params = {
            'searchVal': address,
            'returnGeom': 'Y',
            'getAddrDetails': 'Y',
            'pageNum': 1
        }
        req = requests.get(url, params=params)
        results_dict = req.json()
        
        if len(results_dict['results']) > 0:
            coordinates_list.append((results_dict['results'][0]['LATITUDE'], results_dict['results'][0]['LONGITUDE']))
        else:
            coordinates_list.append(None)
    
    return coordinates_list
# Out:
# StatementMeta(, 67ab9028-33b0-45ae-a06e-69ff47ba6cce, 12, Finished, Available, Finished)

# %%
addresslist = [row['address'] for row in merged_df.select('address').collect()]
# Out:
# StatementMeta(, 67ab9028-33b0-45ae-a06e-69ff47ba6cce, 13, Finished, Available, Finished)

# %%
# Set the number of concurrent workers
max_workers = 10
with ThreadPoolExecutor(max_workers=max_workers) as executor:
    future = executor.submit(get_coordinates, addresslist)
    coordinates_list = future.result()

# Print the coordinates
for i, coordinates in enumerate(coordinates_list):
    address = addresslist[i]
    if coordinates is not None:
        print(f"Coordinates for {address}: Latitude={coordinates[0]}, Longitude={coordinates[1]}")
    else:
        print(f"No coordinates found for {address}")
# Out:
# StatementMeta(, 67ab9028-33b0-45ae-a06e-69ff47ba6cce, 14, Finished, Available, Finished)
# Coordinates for 81 REDHILL LANE: Latitude=1.28775818263836, Longitude=103.819493616875
# No coordinates found for 533A HONG LIM MSCP
# Coordinates for 88A REDHILL CLOSE: Latitude=1.28648640197045, Longitude=103.818549711555
# Coordinates for 163 BUKIT MERAH CENTRAL: Latitude=1.28366139597446, Longitude=103.817072717954
# Coordinates for 43 HOLLAND DRIVE: Latitude=1.30743411126247, Longitude=103.792897574712
# Coordinates for 451 CLEMENTI AVENUE 3: Latitude=1.31248109025097, Longitude=103.765476495005
# Coordinates for 8A EMPRESS ROAD: Latitude=1.31671096509977, Longitude=103.80618154733
# Coordinates for 334 CLEMENTI AVENUE 2: Latitude=1.31518502692041, Longitude=103.768432708555
# Coordinates for 54 TEBAN GARDENS: Latitude=1.32159846468451, Longitude=103.736923103215
# Coordinates for 109 BUKIT PURMEI ROAD: Latitude=1.27392939929265, Longitude=103.825310761145
# Coordinates for 25 TEBAN GARDENS: Latitude=1.32307929386097, Longitude=103.737791107104
# Coordinates for 61 TEBAN GARDENS ROAD: Latitude=1.32213636287766, Longitude=103.738292803395
# Coordinates for 142 JALAN BUKIT MERAH: Latitude=1.27700823497374, Longitude=103.828056201882
# Coordinates for 50 HOY FATT ROAD: Latitude=1.2878771583612, Longitude=103.811440922662
# Coordinates for 59 LENGKOK BAHRU: Latitude=1.28879800625502, Longitude=103.814352116968
# Coordinates for 8: Latitude=1.30054947410356, Longitude=103.846277669472
# Coordinates for 684 HOUGANG STREET 61: Latitude=1.37423751827841, Longitude=103.886931357484
# Coordinates for 578A PASIR RIS STREET 53: Latitude=1.37398648505268, Longitude=103.946600447575
# Coordinates for 586A PASIR RIS STREET 53: Latitude=1.37473187513749, Longitude=103.947756649174
# Coordinates for 515 TAMPINES CENTRAL 7: Latitude=1.35714226544438, Longitude=103.938822366113
# Coordinates for 518 TAMPINES CENTRAL 7: Latitude=1.35619327933532, Longitude=103.93882755214
# Coordinates for AVENUE 3: Latitude=1.32074436688867, Longitude=103.889664147401
# Coordinates for 896 TAMPINES STREET 81: Latitude=1.34830327385557, Longitude=103.932451735683
# Coordinates for 202A TAMPINES STREET 21: Latitude=1.35340749851578, Longitude=103.952209726372
# Coordinates for 201C TAMPINES STREET 21: Latitude=1.35282040093481, Longitude=103.952976398016
# Coordinates for 205 TAMPINES STREET 21: Latitude=1.35171755145102, Longitude=103.951966044566
# No coordinates found for 208A TAMPINES STREET 21
# Coordinates for 201E TAMPINES STREET 21: Latitude=1.35292162536007, Longitude=103.953858335355
# Coordinates for 403 BEDOK NORTH AVENUE 3: Latitude=1.32979984749858, Longitude=103.933844368582
# Coordinates for 413 BEDOK NORTH AVENUE 3: Latitude=1.33030163704738, Longitude=103.931086166936
# Coordinates for 413 BEDOK NORTH AVENUE 2: Latitude=1.33030163704738, Longitude=103.931086166936
# Coordinates for 112 MCNAIR ROAD: Latitude=1.32101349547791, Longitude=103.858982397017
# Coordinates for 108A MCNAIR ROAD: Latitude=1.32055419729917, Longitude=103.859407706602
# Coordinates for 124 MCNAIR ROAD: Latitude=1.31834857200372, Longitude=103.8560612412
# Coordinates for 355 CLEMENTI AVENUE 2: Latitude=1.3144512993879, Longitude=103.769564479655
# No coordinates found for 442A CLEMENTI AVENUE 3
# Coordinates for 462A CLEMENTI AVENUE 3: Latitude=1.31150063886887, Longitude=103.765637479643
# Coordinates for 829 TAMPINES STREET 81: Latitude=1.34922419580696, Longitude=103.934912515373
# Coordinates for 827 TAMPINES STREET 81: Latitude=1.34972149544046, Longitude=103.933719246104
# Coordinates for 823A TAMPINES STREET 81: Latitude=1.3489292582561, Longitude=103.93349188136
# Coordinates for STREET 42: Latitude=1.36774105613039, Longitude=103.852667907643
# Coordinates for 1 THOMSON ROAD: Latitude=1.32559594839311, Longitude=103.842571612968
# Coordinates for 2 BALESTIER ROAD: Latitude=1.32589620218837, Longitude=103.842935480003
# Coordinates for 678 PERUMAL ROAD: Latitude=1.31265810638072, Longitude=103.855327771272
# Coordinates for 75 WHAMPOA DRIVE: Latitude=1.32441875533381, Longitude=103.858185074994
# Coordinates for 98A WHAMPOA DRIVE: Latitude=1.32155040262603, Longitude=103.854634897341
# Coordinates for 85A WHAMPOA DRIVE: Latitude=1.32293305347847, Longitude=103.856298152267
# Coordinates for 37 CIRCUIT ROAD: Latitude=1.32817733374331, Longitude=103.886486362837
# Coordinates for 80 CIRCUIT ROAD: Latitude=1.32783414615937, Longitude=103.887102669236
# Coordinates for 42 CIRCUIT ROAD: Latitude=1.32684923967733, Longitude=103.886293541726
# Coordinates for 43 CIRCUIT ROAD: Latitude=1.32648228290473, Longitude=103.885544901533
# Coordinates for 40 CIRCUIT ROAD: Latitude=1.32767695905654, Longitude=103.886264654446
# Coordinates for 64 CIRCUIT ROAD: Latitude=1.32698404492367, Longitude=103.887148432844
# Coordinates for 66A CIRCUIT ROAD: Latitude=1.32626222140362, Longitude=103.88800264815
# Coordinates for 76 MARINE DRIVE: Latitude=1.3029350083075, Longitude=103.907739044319
# Coordinates for 79 MARINE DRIVE: Latitude=1.30153313447993, Longitude=103.907812007948
# Coordinates for 65A MARINE DRIVE: Latitude=1.30291384106499, Longitude=103.909856191956
# Coordinates for 109 POTONG PASIR AVENUE 1: Latitude=1.33486395185077, Longitude=103.867411589518
# Coordinates for 3: Latitude=1.30393331930705, Longitude=103.829388161578
# Coordinates for 142 POTONG PASIR AVENUE 3: Latitude=1.33320406699901, Longitude=103.866992603867
# Coordinates for 133 POTONG PASIR AVENUE 1: Latitude=1.33431718995826, Longitude=103.865879504187
# Coordinates for 120 POTONG PASIR AVENUE 1: Latitude=1.33545353246777, Longitude=103.863387980398
# Coordinates for 68 LORONG 5 TOA PAYOH: Latitude=1.33480634877878, Longitude=103.852975463498
# Coordinates for 64 LORONG 5 TOA PAYOH: Latitude=1.33568841023376, Longitude=103.852783285399
# No coordinates found for 185 TOA PAYOH TOWN CENTRE
# No coordinates found for 179 TOA PAYOH TOWN CENTRE
# No coordinates found for 193 TOA PAYOH TOWN CENTRE
# Coordinates for C LORONG 4 TOA PAYOH: Latitude=1.33226714462989, Longitude=103.851448927182
# Coordinates for 128A LORONG 1 TOA PAYOH: Latitude=1.33821653776518, Longitude=103.844064129352
# Coordinates for 6 TOA PAYOH: Latitude=1.33858279721249, Longitude=103.85719237771
# Coordinates for 81C LORONG 4 TOA PAYOH: Latitude=1.33578899193238, Longitude=103.849324631706
# Coordinates for 84C LORONG 2 TOA PAYOH: Latitude=1.33577270532514, Longitude=103.847325805217
# Coordinates for 35A LORONG 5 TOA PAYOH: Latitude=1.33488691689286, Longitude=103.854606003745
# No coordinates found for 131 LORONG 2 TOA PAYOH
# Coordinates for 78B TOA PAYOH CENTRAL: Latitude=1.33489515291472, Longitude=103.848566459614
# Coordinates for 138 LORONG 1A TOA PAYOH: Latitude=1.33669264885385, Longitude=103.844796096205
# Coordinates for 104 WHAMPOA DRIVE: Latitude=1.3207995912383, Longitude=103.853327785421
# Coordinates for AVENUE 2: Latitude=1.3088762682627, Longitude=103.766436957496
# Coordinates for 799 YISHUN RING ROAD: Latitude=1.41914050825031, Longitude=103.832592353312
# Coordinates for 935 YISHUN CENTRAL 1: Latitude=1.42518005921711, Longitude=103.836596318713
# Coordinates for 188A BUKIT BATOK WEST AVENUE 6: Latitude=1.34643257279282, Longitude=103.745354017974
# Coordinates for 622A BUKIT BATOK CENTRAL: Latitude=1.35005983483787, Longitude=103.748511881579
# Coordinates for 241 BUKIT PANJANG RING ROAD: Latitude=1.37971696912364, Longitude=103.771871254159
# Coordinates for 245 BUKIT PANJANG RING ROAD: Latitude=1.3805322477834, Longitude=103.772141437385
# Coordinates for 255 BANGKIT ROAD: Latitude=1.37958663519485, Longitude=103.773053180398
# Coordinates for 401A FAJAR ROAD: Latitude=1.38124850337165, Longitude=103.768935381588
# Coordinates for 408 FAJAR ROAD: Latitude=1.38180582760627, Longitude=103.76886288818
# Coordinates for 170A LOMPANG ROAD: Latitude=1.37890449200417, Longitude=103.765567187228
# Coordinates for PENDING ROAD: Latitude=1.37629437059801, Longitude=103.771159112601
# Coordinates for 234A BUKIT PANJANG RING ROAD: Latitude=1.37914274618917, Longitude=103.771998402693
# Coordinates for 163A GANGSA ROAD: Latitude=1.37721649157408, Longitude=103.764324809037
# Coordinates for 180A LOMPANG ROAD: Latitude=1.37870914221803, Longitude=103.76497882643
# Coordinates for 308 ANCHORVALE ROAD: Latitude=1.38955848510235, Longitude=103.886426650492
# Coordinates for 350 BUKIT BATOK STREET 32: Latitude=1.36143858458969, Longitude=103.749152507272
# Coordinates for 149 BUKIT BATOK WEST AVENUE 6: Latitude=1.34928222720369, Longitude=103.744341916695
# Coordinates for 635A JURONG WEST STREET 65: Latitude=1.34241399273627, Longitude=103.698777208379
# Coordinates for 624A JURONG WEST STREET 61: Latitude=1.34113974601716, Longitude=103.69844487756
# Coordinates for 836 WOODLANDS STREET 83: Latitude=1.44041083143799, Longitude=103.791736146198
# Coordinates for 314 PUNGGOL WAY: Latitude=1.4084407415135, Longitude=103.897170952463
# Coordinates for 27 CHAI CHEE ROAD: Latitude=1.32413363919193, Longitude=103.923499790995
# Coordinates for 123 BEDOK NORTH STREET 2: Latitude=1.32919868667839, Longitude=103.937343347878
# Coordinates for 129 BEDOK NORTH STREET 2: Latitude=1.32755443192195, Longitude=103.938030484223
# Coordinates for 364 YUNG AN ROAD: Latitude=1.33714175306825, Longitude=103.720476074938
# Coordinates for 331A KANG CHING ROAD: Latitude=1.33858982415525, Longitude=103.722889900098
# Coordinates for 337 TAH CHING ROAD: Latitude=1.33818197475994, Longitude=103.722602542931
# Coordinates for 256A ANG MO KIO STREET 21: Latitude=1.37039570498099, Longitude=103.835904572804
# Coordinates for 255A ANG MO KIO STREET 21: Latitude=1.37042907046759, Longitude=103.834671279085
# Coordinates for PETIR ROAD: Latitude=1.37482144174585, Longitude=103.771091373899
# Coordinates for 604A CHOA CHU KANG STREET 62: Latitude=1.39744286860326, Longitude=103.745137197199
# Coordinates for 151 BISHAN STREET 11: Latitude=1.34507321944682, Longitude=103.855542321231
# Coordinates for 2: Latitude=1.29644995684098, Longitude=103.834439535286
# Coordinates for 264 SERANGOON CENTRAL: Latitude=1.35227408330171, Longitude=103.872103199544
# Coordinates for 263 SERANGOON CENTRAL: Latitude=1.35386322697735, Longitude=103.871939623369
# Coordinates for 263 SERANGOON CENTRAL: Latitude=1.35386322697735, Longitude=103.871939623369
# Coordinates for 254 SERANGOON CENTRAL DRIVE: Latitude=1.35406229913885, Longitude=103.871216925982
# No coordinates found for 265 SERANGOON AVENUE 3
# Coordinates for 150 SERANGOON NORTH AVENUE 2: Latitude=1.36939950575998, Longitude=103.875014764105
# Coordinates for 323 SENGKANG EAST WAY: Latitude=1.39327134736508, Longitude=103.892577031506
# Coordinates for 6A FARRER ROAD: Latitude=1.31687137905276, Longitude=103.807476001987
# Coordinates for 513A JELAPANG ROAD: Latitude=1.38796662178371, Longitude=103.767437777556
# Coordinates for 518A JELAPANG ROAD: Latitude=1.38666740618483, Longitude=103.766858717024
# Coordinates for 517A JELAPANG ROAD: Latitude=1.38782709901626, Longitude=103.766568774683
# Coordinates for 521A JELAPANG ROAD: Latitude=1.38708094752497, Longitude=103.76595706867
# Coordinates for 525A JELAPANG ROAD: Latitude=1.38631657883814, Longitude=103.76536874357
# Coordinates for 529A JELAPANG ROAD: Latitude=1.38547805958728, Longitude=103.764645457074
# Coordinates for 115 LORONG 1 TOA PAYOH: Latitude=1.34063140668544, Longitude=103.844305221987
# Coordinates for 533A BUKIT PANJANG RING ROAD: Latitude=1.3851549259929, Longitude=103.76345707595
# Coordinates for 537A BUKIT PANJANG RING ROAD: Latitude=1.38411627900246, Longitude=103.762864228212
# Coordinates for 541A BUKIT PANJANG RING ROAD: Latitude=1.38274827647453, Longitude=103.762972057121
# Coordinates for 541A CHOA CHU KANG STREET 52: Latitude=1.39306409609788, Longitude=103.744756328406
# Coordinates for 421 ANG MO KIO AVENUE 10: Latitude=1.36538422642267, Longitude=103.852966961527
# No coordinates found for 460 ANG MO KIO STREET 44
# Coordinates for 221 CHOA CHU KANG CENTRAL: Latitude=1.38222959408828, Longitude=103.745057027229
# Coordinates for CENTRAL: Latitude=1.32496457628748, Longitude=103.932948087606
# Coordinates for 559A CHOA CHU KANG NORTH 6: Latitude=1.396169309968, Longitude=103.744276136696
# Coordinates for 708A CHOA CHU KANG STREET 53: Latitude=1.39097808991265, Longitude=103.746429376017
# Coordinates for 792A CHOA CHU KANG NORTH 6: Latitude=1.39527409432512, Longitude=103.749534434215
# Coordinates for 787A CHOA CHU KANG DRIVE: Latitude=1.39524038527168, Longitude=103.747698862033
# Coordinates for 530 SERANGOON NORTH AVENUE 4: Latitude=1.37339499084047, Longitude=103.872462890152
# Coordinates for 542 SERANGOON NORTH AVENUE 4: Latitude=1.37409116805565, Longitude=103.871889651813
# Coordinates for 542A SERANGOON NORTH AVENUE 4: Latitude=1.37352816200599, Longitude=103.87169704269
# Coordinates for 603A SENJA ROAD: Latitude=1.3817849114234, Longitude=103.761702753806
# Coordinates for 343A CHOA CHU KANG LOOP: Latitude=1.38383719191697, Longitude=103.745948842956
# Coordinates for 527A CHOA CHU KANG STREET 51: Latitude=1.39229089399419, Longitude=103.74107061678
# Coordinates for 552A CHOA CHU KANG STREET 52: Latitude=1.3940650950487, Longitude=103.742208414075
# Coordinates for 337 ANG MO KIO AVENUE 8: Latitude=1.37654743845339, Longitude=103.83413816301
# No coordinates found for 172 ANG MO KIO STREET 13
# Coordinates for 176 ANG MO KIO AVENUE 4: Latitude=1.3758482258358, Longitude=103.83615719919
# No coordinates found for 203 ANG MO KIO STREET 22
# Coordinates for 259 ANG MO KIO AVENUE 2: Latitude=1.36858148248531, Longitude=103.831557777899
# Coordinates for 625A SENJA ROAD: Latitude=1.38633735157449, Longitude=103.760784478073
# Coordinates for 629A SENJA ROAD: Latitude=1.3859775345712, Longitude=103.758963089236
# Coordinates for 762A CHOA CHU KANG NORTH 5: Latitude=1.39260759528275, Longitude=103.749144851986
# Coordinates for 771A CHOA CHU KANG STREET 54: Latitude=1.39453297843943, Longitude=103.749964278203
# Coordinates for 506B SERANGOON NORTH AVENUE 4: Latitude=1.37247361637556, Longitude=103.875802118899
# Coordinates for 504A SERANGOON NORTH AVENUE 4: Latitude=1.37399768680103, Longitude=103.875704727628
# Coordinates for 550A SERANGOON NORTH AVENUE 3: Latitude=1.37256061020502, Longitude=103.870003321094
# Coordinates for 510A JELAPANG ROAD: Latitude=1.38704373320297, Longitude=103.768983568774
# Coordinates for 408 CHOA CHU KANG AVENUE 3: Latitude=1.37991383605328, Longitude=103.740467037393
# Coordinates for 610A CHOA CHU KANG STREET 62: Latitude=1.39879247669957, Longitude=103.743476760839
# Coordinates for 611A CHOA CHU KANG STREET 62: Latitude=1.40044824585964, Longitude=103.743711954064
# Coordinates for 4: Latitude=1.37345849790283, Longitude=103.752898593565
# Coordinates for 621A CHOA CHU KANG NORTH 7: Latitude=1.39963692638659, Longitude=103.747572646388
# Coordinates for 413 CHOA CHU KANG AVENUE 3: Latitude=1.38132792158886, Longitude=103.742568460559
# Coordinates for 420 CHOA CHU KANG AVENUE 4: Latitude=1.38147127512783, Longitude=103.741375947485
# Coordinates for 428 CHOA CHU KANG AVENUE 4: Latitude=1.38123953345099, Longitude=103.739992955985
# Coordinates for 250 CHOA CHU KANG AVENUE 2: Latitude=1.37930897796883, Longitude=103.745365161971
# Coordinates for 251A CHOA CHU KANG AVENUE 2: Latitude=1.37875601115902, Longitude=103.744944334031
# Coordinates for 152A GANGSA ROAD: Latitude=1.37552182453518, Longitude=103.765438473784
# Coordinates for 441 CHOA CHU KANG AVENUE 4: Latitude=1.38292240385745, Longitude=103.739807246356
# Coordinates for 437 CHOA CHU KANG AVENUE 4: Latitude=1.38410980069154, Longitude=103.740645540511
# Coordinates for 511A CHOA CHU KANG STREET 51: Latitude=1.38859055468141, Longitude=103.741106691297
# Coordinates for 429A CHOA CHU KANG AVENUE 4: Latitude=1.38342388676801, Longitude=103.740852261839
# No coordinates found for 140 CASHEW ROAD
# Coordinates for 651A SENJA LINK: Latitude=1.38649140113072, Longitude=103.76397892473
# Coordinates for 502A CHOA CHU KANG STREET 51: Latitude=1.38871470811511, Longitude=103.742956268034
# No coordinates found for 453 ANG MO KIO STREET 43
# Coordinates for 405 ANG MO KIO AVENUE 10: Latitude=1.36157912717139, Longitude=103.853805386957
# No coordinates found for 626 ANG MO KIO STREET 61
# Coordinates for 626 ANG MO KIO AVENUE 4: Latitude=1.38109958326678, Longitude=103.839964624538
# No coordinates found for 632 ANG MO KIO STREET 61
# Coordinates for 567A CHOA CHU KANG STREET 52: Latitude=1.39539827865869, Longitude=103.746154243249
# No coordinates found for 476 ANG MO KIO STREET 44
# Coordinates for 603 ANG MO KIO AVENUE 5: Latitude=1.38020079047279, Longitude=103.83575571651
# No coordinates found for 627 ANG MO KIO STREET 61
# No coordinates found for 134 ANG MO KIO STREET 12
# Coordinates for 130A ANG MO KIO STREET 12: Latitude=1.37070330698832, Longitude=103.841898346105
# Coordinates for 132A ANG MO KIO STREET 12: Latitude=1.37170680912113, Longitude=103.84196151089
# Coordinates for 40 CHAI CHEE AVENUE: Latitude=1.32604335303082, Longitude=103.926488452026
# No coordinates found for 34A BED0K SOUTH AVENUE 2
# Coordinates for STREET 91: Latitude=1.37708638977268, Longitude=103.882310053371
# Coordinates for 637A BEDOK RESERVOIR ROAD: Latitude=1.3305542567747, Longitude=103.904332844895
# Coordinates for 629 BEDOK RESERVOIR ROAD: Latitude=1.33439908281466, Longitude=103.914501162624
# Coordinates for 624 BEDOK RESERVOIR ROAD: Latitude=1.33430060482328, Longitude=103.916398118478
# Coordinates for 616 BEDOK RESERVOIR ROAD: Latitude=1.33190396095581, Longitude=103.915137759126
# Coordinates for 647 TAMPINES STREET 62: Latitude=1.36739236053972, Longitude=103.941824444979
# Coordinates for 161 JALAN TECK WHYE: Latitude=1.38012990422531, Longitude=103.758203987241
# No coordinates found for 140 BEDOK NORTH AVENUE 3
# Coordinates for 136 BEDOK NORTH AVENUE 3: Latitude=1.32815498828204, Longitude=103.93522082327
# Coordinates for 133 BEDOK NORTH AVENUE 3: Latitude=1.32756257230307, Longitude=103.93573462699
# Coordinates for 132 BEDOK NORTH STREET 2: Latitude=1.32775288998395, Longitude=103.936709340476
# Coordinates for 431 BEDOK NORTH ROAD: Latitude=1.32922126388158, Longitude=103.932502461445
# Coordinates for 57 DAWSON RD: Latitude=1.29270339855062, Longitude=103.810958956467
# Coordinates for 60A STRATHMORE AVENUE: Latitude=1.29259189038649, Longitude=103.811870487196
# Coordinates for 883A WOODLANDS ST 82: Latitude=1.44313413100075, Longitude=103.791040687991
# Coordinates for 475 CHOA CHU KANG AVENUE 3: Latitude=1.37805614752086, Longitude=103.738931794069
# Coordinates for 399 YUNG SHENG ROAD: Latitude=1.3350420286067, Longitude=103.72026802061
# Coordinates for 762A JURONG WEST ST 75: Latitude=1.34903891716534, Longitude=103.697919052195
# Coordinates for 446A FAJAR ROAD: Latitude=1.38377798738412, Longitude=103.771350678551
# Coordinates for 548 WOODLANDS DR 44: Latitude=1.43044361849124, Longitude=103.793804884379
# Coordinates for 888A WOODLANDS DR 50: Latitude=1.43810900697977, Longitude=103.7951500999
# Coordinates for 337 TAH CHING ROAD: Latitude=1.33818197475994, Longitude=103.722602542931
# Coordinates for 132 CANBERRA VIEW: Latitude=1.44340777310418, Longitude=103.830807359933
# Coordinates for 126 CANBERRA STREET: Latitude=1.44602265750894, Longitude=103.834372150393
# Coordinates for 445 CLEMENTI AVENUE 3: Latitude=1.31335932628171, Longitude=103.763902569669
# Coordinates for 748 BEDOK RESERVOIR CRESCENT: Latitude=1.33610258444527, Longitude=103.921882717493
# Coordinates for 463 BUKIT BATOK STREET 41: Latitude=1.35683551267825, Longitude=103.741447348978
# Coordinates for 117 CANBERRA CRESCENT: Latitude=1.44510882167817, Longitude=103.829914452128
# Coordinates for 80 STRATHMORE AVENUE: Latitude=1.2945613912197, Longitude=103.809692095051
# Coordinates for 315C ANCHORVALE ROAD: Latitude=1.39234414519167, Longitude=103.888049808731
# No coordinates found for 302 CHOA CHU KANG LOOP
# Coordinates for 875A TAMPINES STREET 86: Latitude=1.35350798820875, Longitude=103.929903035359
# Coordinates for 647A JURONG WEST STREET 61: Latitude=1.33984244458379, Longitude=103.696805203541
# Coordinates for 463 CLEMENTI AVENUE 1: Latitude=1.31096580515636, Longitude=103.767863406037
# Coordinates for 14A KAMPONG ARANG ROAD: Latitude=1.30034301357639, Longitude=103.883651172776
# Coordinates for 542 SERANGOON NORTH AVENUE 4: Latitude=1.37409116805565, Longitude=103.871889651813
# Coordinates for BUANGKOK LINK: Latitude=1.38298989425357, Longitude=103.882287586267
# Coordinates for 993 BUANGKOK LINK: Latitude=1.38511499043052, Longitude=103.88362378135
# Coordinates for 7 HOUGANG AVENUE 3: Latitude=1.36232721881747, Longitude=103.893510807642
# Coordinates for 227 ANG MO KIO STREET 23: Latitude=1.36877838877909, Longitude=103.840273944362
# Coordinates for 2 BEACH ROAD: Latitude=1.30403300585898, Longitude=103.864928408355
# Coordinates for 3 BEACH ROAD: Latitude=1.30418712919936, Longitude=103.86519331441
# Coordinates for 467 BUKIT BATOK WEST AVENUE 9: Latitude=1.35713012350104, Longitude=103.743465010621
# Coordinates for 547C BEDOK NORTH AVENUE 1: Latitude=1.32998302575378, Longitude=103.92558945805
# Coordinates for 873A TAMPINES STREET 85: Latitude=1.35487419110579, Longitude=103.930658014258
# Coordinates for 872A TAMPINES STREET 86: Latitude=1.35552061304029, Longitude=103.931104551713
# Coordinates for 377 HOUGANG STREET 32: Latitude=1.36274851459883, Longitude=103.894906998774
# Coordinates for 647 TAMPINES STREET 62: Latitude=1.36739236053972, Longitude=103.941824444979
# Coordinates for 519 JELAPANG ROAD: Latitude=1.38774050396782, Longitude=103.766289444489
# Coordinates for 95A DAWSON ROAD: Latitude=1.29608900588749, Longitude=103.811942985939
# Coordinates for 478 YISHUN STREET 42: Latitude=1.42939025205716, Longitude=103.850709781984
# No coordinates found for 534 BUKIT PANJANG RING ROAD
# Coordinates for 681 PUNGGOL DR: Latitude=1.40259581502678, Longitude=103.912962428692
# Coordinates for 618 TAMPINES STREET 61: Latitude=1.36180279850885, Longitude=103.94006795101
# Coordinates for 10: Latitude=1.31615491830399, Longitude=103.840533848314
# Coordinates for 661 YISHUN AVENUE 4: Latitude=1.42201523201179, Longitude=103.840714295544
# Coordinates for 113 ALKAFF CRESCENT: Latitude=1.33525150016811, Longitude=103.872943178739
# Coordinates for 692A JURONG WEST CENTRAL 3: Latitude=1.34171964715954, Longitude=103.707150568487
# Coordinates for 118 ANG MO KIO AVENUE 4: Latitude=1.37329593649654, Longitude=103.835475719134
# Coordinates for 154 BEDOK SOUTH ROAD: Latitude=1.31789091823444, Longitude=103.946338598685
# Coordinates for 152A BEDOK SOUTH ROAD: Latitude=1.31767817684758, Longitude=103.947397456277
# Coordinates for 408 SIN MING AVENUE: Latitude=1.36334651886138, Longitude=103.834839633876
# Coordinates for 410A SIN MING AVENUE: Latitude=1.36321663626182, Longitude=103.835456921925
# Coordinates for 222 BEDOK NORTH DRIVE: Latitude=1.32449197461735, Longitude=103.927900348438
# Coordinates for 201 WOODLEIGH LINK: Latitude=1.34037360349272, Longitude=103.872220917139
# Coordinates for 207 WOODLEIGH LINK: Latitude=1.34179406261862, Longitude=103.871440863061
# Coordinates for 206 WOODLEIGH LINK: Latitude=1.34135946989774, Longitude=103.872216426872
# Coordinates for 338A ANCHORVALE CRESCENT: Latitude=1.39926289122119, Longitude=103.888859316617
# Coordinates for 212 BIDADARI PARK DRIVE: Latitude=1.34279948643004, Longitude=103.875178060687
# Coordinates for 999B BUANGKOK CRESCENT: Latitude=1.38453689339832, Longitude=103.880588848601
# Coordinates for 992B BUANGKOK LINK: Latitude=1.3838267304931, Longitude=103.881672473881
# Coordinates for 106 CANBERRA STREET: Latitude=1.44913843217997, Longitude=103.832773396234
# Coordinates for 129 CANBERRA STREET: Latitude=1.44462701611109, Longitude=103.832728826428
# Coordinates for 108 CANBERRA WALK: Latitude=1.44776611412274, Longitude=103.83222301056
# Coordinates for 115 CANBERRA WALK: Latitude=1.44608188224858, Longitude=103.828739863564
# Coordinates for 671 YISHUN AVENUE 4: Latitude=1.4191911631409, Longitude=103.841581271297
# Coordinates for 673 YISHUN AVENUE 4: Latitude=1.41967264727606, Longitude=103.841716733969
# Coordinates for 676 YISHUN RING ROAD: Latitude=1.42162829335003, Longitude=103.841810408056
# Coordinates for 462A CLEMENTI AVENUE 3: Latitude=1.31150063886887, Longitude=103.765637479643
# Coordinates for 208 CLEMENTI AVENUE 6: Latitude=1.32239580834597, Longitude=103.762120086045
# Coordinates for 78A DAWSON ROAD: Latitude=1.29424818868024, Longitude=103.810133833776
# Coordinates for 7 EVERTON PARK: Latitude=1.27692435153003, Longitude=103.838679504443
# No coordinates found for 6A EVERTON ROAD
# Coordinates for 96 HENDERSON ROAD: Latitude=1.28754332229134, Longitude=103.821335072268
# Coordinates for 134A JALAN BUKIT MERAH: Latitude=1.27925619858448, Longitude=103.827209347314
# Coordinates for 113A JALAN BUKIT MERAH: Latitude=1.2802491885155, Longitude=103.825273102894
# Coordinates for 415 PANDAN GARDENS: Latitude=1.32076543342048, Longitude=103.748258626828
# Coordinates for 80 STRATHMORE AVENUE: Latitude=1.2945613912197, Longitude=103.809692095051
# Coordinates for 114 DEPOT ROAD: Latitude=1.28175927117793, Longitude=103.806862236642
# Coordinates for 90B TELOK BLANGAH STREET 31: Latitude=1.27728367741324, Longitude=103.806916176715
# Coordinates for 90 TELOK BLANGAH STREET 31: Latitude=1.27719861370751, Longitude=103.807254878543
# Coordinates for 107 JALAN BUKIT MERAH: Latitude=1.27983690191197, Longitude=103.824757769108
# Coordinates for 112 JALAN BUKIT MERAH: Latitude=1.28000480135122, Longitude=103.82601329621
# Coordinates for 138 JALAN BUKIT MERAH: Latitude=1.27842357024921, Longitude=103.826237590943
# Coordinates for 63A TEBAN GARDENS ROAD: Latitude=1.32117309678601, Longitude=103.73893235112
# No coordinates found for 64 AND 65 TEBAN GARDENS ROAD
# Coordinates for 651 ANG MO KIO AVENUE 9: Latitude=1.3830203830033, Longitude=103.841780326812
# Coordinates for 21 MARSILING LANE: Latitude=1.44344416787521, Longitude=103.776989477833
# Coordinates for PLANTATION CRESCENT: Latitude=1.35695784234263, Longitude=103.733744860385
# Coordinates for 126C TENGAH DRIVE: Latitude=1.35842084419546, Longitude=103.735075392179
# Coordinates for 128B PLANTATION CRESCENT: Latitude=1.35819333270429, Longitude=103.733604557564
# Coordinates for 149 TOWNER ROAD: Latitude=1.31832960459766, Longitude=103.859383978238
# Coordinates for 446 PUNGGOL WAY: Latitude=1.41705069091257, Longitude=103.912693600693
# Coordinates for KEMPAS ROAD: Latitude=1.31526498189222, Longitude=103.859699572452
# Coordinates for 960 TAMPINES STREET 96: Latitude=1.33976534530304, Longitude=103.937219373903
# Coordinates for B TENGAH GARDEN WALK: Latitude=1.35937881017565, Longitude=103.729690319627
# Coordinates for 218 TENGAH GARDEN WALK: Latitude=1.35962999230679, Longitude=103.730410533186
# Coordinates for 379 CANBERRA DRIVE: Latitude=1.44086147315223, Longitude=103.828539259164
# Coordinates for 374 CANBERRA DRIVE: Latitude=1.44452273500325, Longitude=103.828488951168
# Coordinates for 567 CHAMPIONS WAY: Latitude=1.42801113602749, Longitude=103.788742088987
# Coordinates for 482 YISHUN AVENUE 6: Latitude=1.43172898326772, Longitude=103.849212545971
# Coordinates for 240 TENGAH GARDEN WALK: Latitude=1.36061578677807, Longitude=103.732199052701
# Coordinates for 665 TAMPINES STREET 64: Latitude=1.37068121533819, Longitude=103.935984454855
# No coordinates found for 230 ANG MO KIO STREET 22
# No coordinates found for 233 ANG MO KIO STREET 22
# No coordinates found for 254 ANG MO KIO STREET 21
# Coordinates for 10: Latitude=1.31615491830399, Longitude=103.840533848314
# Coordinates for 455 ANG MO KIO STREET 44: Latitude=1.36861890810982, Longitude=103.857301050004
# Coordinates for 504 BISHAN STREET 11: Latitude=1.34930004584838, Longitude=103.848484732399
# Coordinates for 513 BISHAN STREET 13: Latitude=1.34946633905282, Longitude=103.849467349041
# Coordinates for 514 BISHAN STREET 13: Latitude=1.35011694205963, Longitude=103.849763180442
# Coordinates for 263A BISHAN STREET 22: Latitude=1.35918439853156, Longitude=103.841954553107
# Coordinates for 275 BISHAN STREET 24: Latitude=1.35696035958998, Longitude=103.843293847923
# No coordinates found for 121A AND 121B CANBERRA STREET
# Coordinates for CANBERRA CRESCENT: Latitude=1.44668569489023, Longitude=103.829892157106
# Coordinates for 120 CANBERRA CRESCENT: Latitude=1.44565250579578, Longitude=103.831432705545
# Coordinates for 365 SEMBAWANG CRESCENT: Latitude=1.44436832551494, Longitude=103.816263881257
# Coordinates for 237 SERANGOON AVENUE 3: Latitude=1.35381198342473, Longitude=103.87013457465
# Coordinates for 520 SERANGOON NORTH AVENUE 4: Latitude=1.37203549075077, Longitude=103.873724425334
# Coordinates for 238A SERANGOON AVENUE 2: Latitude=1.35391111924878, Longitude=103.868602093981
# Coordinates for 226 SERANGOON AVENUE 4: Latitude=1.35682249995275, Longitude=103.87085702772
# Coordinates for 141 SERANGOON NORTH AVENUE 2: Latitude=1.36859421304209, Longitude=103.874523243764
# Coordinates for 179 WOODLANDS STREET 13: Latitude=1.43477628027223, Longitude=103.778216808762
# Coordinates for 335 WOODLANDS STREET 32: Latitude=1.42972520117129, Longitude=103.780579357988
# Coordinates for 836 WOODLANDS STREET 83: Latitude=1.44041083143799, Longitude=103.791736146198
# Coordinates for 574 WOODLANDS DRIVE 16: Latitude=1.43057087053253, Longitude=103.798454797735
# Coordinates for 693 WOODLANDS AVENUE 6: Latitude=1.43808788056635, Longitude=103.803764959272
# Coordinates for 694 WOODLANDS DRIVE 62: Latitude=1.43805327667813, Longitude=103.804989130685
# Coordinates for 785 WOODLANDS RISE: Latitude=1.4470866052223, Longitude=103.804996805647
# No coordinates found for 102 YISHUN AVENUE 5
# Coordinates for 111 YISHUN RING ROAD: Latitude=1.43321263970177, Longitude=103.828617498413
# Coordinates for AVENUE 2: Latitude=1.3088762682627, Longitude=103.766436957496
# Coordinates for 799 YISHUN RING ROAD: Latitude=1.41914050825031, Longitude=103.832592353312
# Coordinates for 925 YISHUN CENTRAL 1: Latitude=1.42750549654333, Longitude=103.837125284539
# Coordinates for 935 YISHUN CENTRAL 1: Latitude=1.42518005921711, Longitude=103.836596318713
# Coordinates for 513C YISHUN STREET 51: Latitude=1.41540780549145, Longitude=103.84380144741
# Coordinates for 513 YISHUN STREET 51: Latitude=1.41600486949205, Longitude=103.844251717032
# Coordinates for 501 YISHUN STREET 51: Latitude=1.4165674773128, Longitude=103.840902686823
# Coordinates for 461 YISHUN AVENUE 6: Latitude=1.42841338853064, Longitude=103.84997365333
# Coordinates for 468 YISHUN STREET 43: Latitude=1.42477394982863, Longitude=103.851792560531
# Coordinates for 180 HOUGANG STREET 12: Latitude=1.34631621182229, Longitude=103.890099192756
# Coordinates for 270 TOA PAYOH EAST: Latitude=1.33369641263342, Longitude=103.859096360145
# Coordinates for 227 BARTLEY WALK: Latitude=1.34024749735901, Longitude=103.876330655485
# Coordinates for 119 ALKAFF CRESCENT: Latitude=1.33674489248516, Longitude=103.874525998995
# Coordinates for 10A BEDOK SOUTH AVENUE 2: Latitude=1.32258561622604, Longitude=103.936849426204
# Coordinates for 659 PUNGGOL EAST: Latitude=1.40101753350583, Longitude=103.919583795626

# %%
# Remove None values
coordinates_list_clean = [coord for coord in coordinates_list if coord is not None]

# Create Spark DataFrame
df_coordinates = spark.createDataFrame(coordinates_list_clean)
# Out:
# StatementMeta(, 67ab9028-33b0-45ae-a06e-69ff47ba6cce, 15, Finished, Available, Finished)

# %%
df1 = merged_df.withColumn("row_id", monotonically_increasing_id())
df2 = df_coordinates.withColumn("row_id", monotonically_increasing_id())

carpark_final = df1.join(df2, on="row_id", how="inner").drop("row_id")

carpark_final = carpark_final.withColumnRenamed('_1', 'Latitude')
carpark_final = carpark_final.withColumnRenamed('_2', 'Longitude')
carpark_final = carpark_final.drop("x_coord", "y_coord")

# Replace 'None' string with null in all columns
carpark_final = carpark_final.select(
    [when(col(c) == 'None', None).otherwise(col(c)).alias(c) for c in carpark_final.columns]
)

# Drop rows with any null values
carpark_final = carpark_final.na.drop()

carpark_final = (
    carpark_final
    .withColumn("Latitude", col("Latitude").cast("double"))
    .withColumn("Longitude", col("Longitude").cast("double"))
)

carpark_final = carpark_final.withColumn(
    "Availability",
    round(
        when(col("total_lots") != 0, (col("lots_available") / col("total_lots")) * 100)
        .otherwise(None), 
        1
    )
)

carpark_final.printSchema()
carpark_final.count()
# Out:
# StatementMeta(, 67ab9028-33b0-45ae-a06e-69ff47ba6cce, 16, Finished, Available, Finished)
# root
#  |-- carpark_number: string (nullable = true)
#  |-- lots_available: long (nullable = true)
#  |-- total_lots: long (nullable = true)
#  |-- update_datetime: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- car_park_type: string (nullable = true)
#  |-- type_of_parking_system: string (nullable = true)
#  |-- short_term_parking: string (nullable = true)
#  |-- free_parking: string (nullable = true)
#  |-- night_parking: string (nullable = true)
#  |-- car_park_decks: integer (nullable = true)
#  |-- gantry_height: double (nullable = true)
#  |-- car_park_basement: string (nullable = true)
#  |-- Latitude: double (nullable = true)
#  |-- Longitude: double (nullable = true)
#  |-- Availability: double (nullable = true)
# 1910

# %%
# Save to Fabric Lakehouse (Delta format)
carpark_final.write.format("delta").mode("overwrite").save("Tables/CarparkAvailability")

print(f"✅ Ingested {carpark_final.count()} carpark records into Lakehouse.")
# Out:
# StatementMeta(, 67ab9028-33b0-45ae-a06e-69ff47ba6cce, 17, Finished, Available, Finished)
# ✅ Ingested 1910 carpark records into Lakehouse.

# %%
# Check for NULLs in key columns
spark.table("CarparkAvailability").filter(
    col("lots_available").isNull() | 
    col("total_lots").isNull() |
    col("address").isNull()
).count()
# Out:
# StatementMeta(, 67ab9028-33b0-45ae-a06e-69ff47ba6cce, 18, Finished, Available, Finished)
# 0

# %% [markdown]
# #### Historical_Stats

# %% [markdown]
# ##### The historical_stats table serves as a preprocessed summary of the carpark availability data, designed specifically to power the RAG (Retrieval-Augmented Generation) system. Its core purpose is to Aggregates Raw Data, Creates Semantic Context (generates human-readable text summaries (the context column)) and Cleans & Standardizes Data to ensure consistent formatting for embeddings.

# %%
from pyspark.sql.functions import col, avg, expr, lit, coalesce, concat

historical_stats = (
    spark.table("CarparkAvailability")
    # Safely cast to integers (returns NULL if conversion fails)
    .withColumn("lots_available", expr("TRY_CAST(lots_available AS INT)"))
    .withColumn("total_lots", expr("TRY_CAST(total_lots AS INT)"))
    # Replace zeros in total_lots to avoid division errors
    .withColumn("total_lots_safe", 
                expr("CASE WHEN total_lots IS NULL OR total_lots = 0 THEN 1 ELSE total_lots END"))
    # Calculate average occupancy (handle NULLs with coalesce)
    .groupBy("carpark_number", "address")
    .agg(
        coalesce(
            avg(col("lots_available") / col("total_lots_safe")), 
            lit(0.0)
        ).alias("avg_availability")
    )
    # Build context string (handle NULL address)
    .withColumn(
        "context", 
        concat(
            coalesce(col("address"), lit("Unknown")), 
            lit(" averages "), 
            (col("avg_availability") * 100).cast("string"), 
            lit("% availability.")
        )
    )
    .select("carpark_number", "context")
)

# Show results
historical_stats.show(10, truncate=False)
# Out:
# StatementMeta(, 67ab9028-33b0-45ae-a06e-69ff47ba6cce, 19, Finished, Available, Finished)
# +--------------+---------------------------------------------------------------------+
# |carpark_number|context                                                              |
# +--------------+---------------------------------------------------------------------+
# |CK47          |787A CHOA CHU KANG DRIVE averages 76.69064748201438% availability.   |
# |BJ30          |510A JELAPANG ROAD averages 73.81342062193126% availability.         |
# |BJ43          |603A SENJA ROAD averages 78.28685258964143% availability.            |
# |AM96          |352A ANG MO KIO STREET 32 averages 63.23809523809524% availability.  |
# |U34           |511 BUKIT BATOK STREET 52 averages 51.81518151815182% availability.  |
# |A72           |640 ANG MO KIO STREET 61 averages 59.217877094972074% availability.  |
# |B35           |140 BEDOK NORTH AVENUE 3 averages 40.10152284263959% availability.   |
# |Q84           |32 HOLLAND CLOSE averages 19.53125% availability.                    |
# |CK3           |124 TECK WHYE LANE averages 52.12765957446809% availability.         |
# |J84M          |854A JURONG WEST STREET 81 averages 63.859649122807014% availability.|
# +--------------+---------------------------------------------------------------------+
# only showing top 10 rows

# %% [markdown]
# #### Generating embeddings_table

# %% [markdown]
# ##### The embedding_table is the engine that powers the semantic search capability in the RAG (Retrieval-Augmented Generation) system. It enables Efficient Similarity Calculation (i.e. cosine similarity comparisons)

# %%
from pyspark.sql.functions import pandas_udf
import pandas as pd

@pandas_udf(ArrayType(FloatType()))
def get_embeddings_udf(texts: pd.Series) -> pd.Series:
    client = OpenAI(api_key="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")
    embeddings = []
    for text in texts:
        if not text:
            embeddings.append([0.0]*1536)
            continue
        response = client.embeddings.create(
            input=text,
            model="text-embedding-3-small"
        )
        embeddings.append(response.data[0].embedding)
    return pd.Series(embeddings)

embeddings_table = historical_stats.withColumn(
    "embedding",
    get_embeddings_udf(col("context"))
)
print(embeddings_table.show())
# Out:
# StatementMeta(, 67ab9028-33b0-45ae-a06e-69ff47ba6cce, 20, Finished, Available, Finished)
# +--------------+--------------------+--------------------+
# |carpark_number|             context|           embedding|
# +--------------+--------------------+--------------------+
# |          CK47|787A CHOA CHU KAN...|[-0.051202085, 0....|
# |          BJ30|510A JELAPANG ROA...|[-0.04415941, 0.0...|
# |          BJ43|603A SENJA ROAD a...|[-0.03051225, 0.0...|
# |          AM96|352A ANG MO KIO S...|[-0.005807804, 0....|
# |           U34|511 BUKIT BATOK S...|[-0.033087425, -0...|
# |           A72|640 ANG MO KIO ST...|[-0.010886977, 0....|
# |           B35|140 BEDOK NORTH A...|[-0.055673484, 0....|
# |           Q84|32 HOLLAND CLOSE ...|[-0.04707278, 0.0...|
# |           CK3|124 TECK WHYE LAN...|[-0.004688993, 0....|
# |          J84M|854A JURONG WEST ...|[-0.039459676, 0....|
# |          SE33|542 SERANGOON NOR...|[-0.04468306, 0.0...|
# |            C9|348 CLEMENTI AVEN...|[-0.05758462, 0.0...|
# |           C24|118 CLEMENTI STRE...|[-0.04234992, 0.0...|
# |           U46|299 BUKIT BATOK S...|[-0.024999563, -0...|
# |          J60M|505A JURONG WEST ...|[-0.034606535, 0....|
# |           BP2|115 BUKIT PURMEI ...|[-0.042317603, 0....|
# |          JM31|638A JURONG WEST ...|[-0.043156248, 0....|
# |          SK68|275 COMPASSVALE L...|[-0.007829769, 0....|
# |          BJ39|537A BUKIT PANJAN...|[-0.044634122, 0....|
# |          CK38|541A CHOA CHU KAN...|[-0.032845274, -0...|
# +--------------+--------------------+--------------------+
# only showing top 20 rows
#
# None

# %% [markdown]
# #### Save Embeddings for Future Use

# %%
embeddings_table.write.format("delta").mode("overwrite").saveAsTable("CarparkEmbeddings")
# Out:
# StatementMeta(, 67ab9028-33b0-45ae-a06e-69ff47ba6cce, 21, Finished, Available, Finished)

# %%
## For faster access later:
spark.sql("OPTIMIZE CarparkEmbeddings ZORDER BY carpark_number")
# Out:
# StatementMeta(, 67ab9028-33b0-45ae-a06e-69ff47ba6cce, 22, Finished, Available, Finished)
# DataFrame[path: string, metrics: struct<numFilesAdded:bigint,numFilesRemoved:bigint,numFilesUpdatedWithoutRewrite:bigint,filesAdded:struct<min:bigint,max:bigint,avg:double,totalFiles:bigint,totalSize:bigint>,filesRemoved:struct<min:bigint,max:bigint,avg:double,totalFiles:bigint,totalSize:bigint>,filesUpdatedWithoutRewrite:struct<min:bigint,max:bigint,avg:double,totalFiles:bigint,totalSize:bigint>,filesRemovedBreakdown:array<struct<reason:string,metrics:struct<min:bigint,max:bigint,avg:double,totalFiles:bigint,totalSize:bigint>>>,partitionsOptimized:bigint,zOrderStats:struct<strategyName:string,inputCubeFiles:struct<num:bigint,size:bigint>,inputOtherFiles:struct<num:bigint,size:bigint>,inputNumCubes:bigint,mergedFiles:struct<num:bigint,size:bigint>,numOutputCubes:bigint,mergedNumCubes:bigint>,clusteringStats:struct<inputZCubeFiles:struct<numFiles:bigint,size:bigint>,inputOtherFiles:struct<numFiles:bigint,size:bigint>,inputNumZCubes:bigint,mergedFiles:struct<numFiles:bigint,size:bigint>,numOutputZCubes:bigint>,numBatches:bigint,totalConsideredFiles:bigint,totalFilesSkipped:bigint,preserveInsertionOrder:boolean,numFilesSkippedToReduceWriteAmplification:bigint,numBytesSkippedToReduceWriteAmplification:bigint,startTimeMs:bigint,endTimeMs:bigint,totalClusterParallelism:bigint,totalScheduledTasks:bigint,autoCompactParallelismStats:struct<maxClusterActiveParallelism:bigint,minClusterActiveParallelism:bigint,maxSessionActiveParallelism:bigint,minSessionActiveParallelism:bigint>,deletionVectorStats:struct<numDeletionVectorsRemoved:bigint,numDeletionVectorRowsRemoved:bigint>,numTableColumns:bigint,numTableColumnsWithStats:bigint>]

# %% [markdown]
# #### Create a Query Function

# %%
from pyspark.sql.functions import pandas_udf, col, lit
import numpy as np

client = OpenAI(api_key=openai.api_key)

def query_carparks(search_query: str, top_n: int = 5):
    """Search carparks by semantic similarity"""
    # Step 1: Get query embedding (outside Spark)
    query_embedding = client.embeddings.create(
        input=search_query,
        model="text-embedding-3-small"
    ).data[0].embedding
    
    # Convert to numpy array for efficient calculations
    query_np = np.array(query_embedding)
    query_norm = np.linalg.norm(query_np)
    
    # Step 2: Define cosine similarity UDF
    @pandas_udf("double")
    def cosine_sim(embeddings: pd.Series) -> pd.Series:
        def _similarity(x):
            if x is None:
                return 0.0
            x_np = np.array(x)
            dot = np.dot(x_np, query_np)
            x_norm = np.linalg.norm(x_np)
            return float(dot / (x_norm * query_norm + 1e-8))  # Prevent division by zero
            
        return embeddings.apply(_similarity)
    
    # Step 3: Run search
    results = (embeddings_table
        .withColumn("similarity", cosine_sim(col("embedding")))
        .orderBy(col("similarity").desc())
        .limit(top_n)
    )
    
    return results
# Out:
# StatementMeta(, 67ab9028-33b0-45ae-a06e-69ff47ba6cce, 23, Finished, Available, Finished)

# %% [markdown]
# ##### Execute a Sample Query

# %%
# Example search
search_results = query_carparks(
    search_query="What do you think would the carpark availability near 109 Bukit Batok for tomorrow?", 
    top_n=3
)

# Show results
search_results.select("carpark_number", "context", "similarity").show(truncate=False)
# Out:
# StatementMeta(, 67ab9028-33b0-45ae-a06e-69ff47ba6cce, 30, Finished, Available, Finished)
# +--------------+------------------------------------------------------------------+------------------+
# |carpark_number|context                                                           |similarity        |
# +--------------+------------------------------------------------------------------+------------------+
# |BBM8          |622A BUKIT BATOK CENTRAL averages 54.7112462006079% availability. |0.6521967706966447|
# |U40           |644A BUKIT BATOK CENTRAL averages 85.76388888888889% availability.|0.6512535689026021|
# |U32           |514 BUKIT BATOK STREET 52 averages 61.71875% availability.        |0.6452455772964272|
# +--------------+------------------------------------------------------------------+------------------+

# %% [markdown]
# #### Generate AI Summaries

# %%
def generate_summary(results_df):
    """Convert search results to natural language"""
    top_matches = "\n".join(
        [f"{row['carpark_number']}: {row['context']} (Score: {row['similarity']:.2f})" 
         for row in results_df.collect()]
    )
    
    response = client.chat.completions.create(
        model="gpt-4",
        messages=[{
            "role": "user",
            "content": f"""Predict these carpark availability for tomorrow:
            {top_matches}
            
            Provide a concise answer to the original query."""
        }],
        max_tokens=200
    )
    return response.choices[0].message.content

print(generate_summary(search_results))
# Out:
# StatementMeta(, 67ab9028-33b0-45ae-a06e-69ff47ba6cce, 31, Finished, Available, Finished)
# Based on the average availability, it is predicted that for tomorrow the carpark at BBM8: 622A Bukit Batok Central will have approximately 54.7% availability, U40: 644A Bukit Batok Central will have approximately 85.8% availability, and U32: 514 Bukit Batok Street 52 will have approximately 61.7% availability.

# %% [markdown]
# #### Performance Optimization

# %%
# Cache frequently used data
embeddings_table.cache()
# Out:
# StatementMeta(, 67ab9028-33b0-45ae-a06e-69ff47ba6cce, 26, Finished, Available, Finished)
# DataFrame[carpark_number: string, context: string, embedding: array<float>]
